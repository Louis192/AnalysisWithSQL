# %% [markdown]
# # Entity relationship diagram

# %% [markdown]
# Below is a construction of ER  diagram for designing the Sales SCHEMA

# %% [markdown]
# ![Screenshot%202023-06-06%20at%202.32.24%20PM.jpg](attachment:Screenshot%202023-06-06%20at%202.32.24%20PM.jpg)

# %% [markdown]
# # Database and Table creation

# %% [markdown]
# Below is a creation of database and schema and to ensure that database is normalized

# %% [markdown]
# ![Screenshot%202023-06-06%20at%202.56.53%20PM.jpg](attachment:Screenshot%202023-06-06%20at%202.56.53%20PM.jpg)

# %% [markdown]
# ![Screenshot%202023-06-06%20at%202.57.40%20PM.jpg](attachment:Screenshot%202023-06-06%20at%202.57.40%20PM.jpg)

# %% [markdown]
# ![Screenshot%202023-06-06%20at%202.58.07%20PM.jpg](attachment:Screenshot%202023-06-06%20at%202.58.07%20PM.jpg)
